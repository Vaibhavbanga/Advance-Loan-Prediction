# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data = pd.read_csv('C:/Users/Vaibhav Banga/Downloads/train_ctrUa4K.csv')

# %%
Data_Test = pd.read_csv("C:/Users/Vaibhav Banga/Downloads/test_lAUu6dG.csv")

# %%
copy = Data_Test.copy()

# %% [markdown]
# # EDA-Exploratory Data Analysis

# %%
Data_Test.drop('Loan_ID',axis = 1,inplace = True)

# %%
Data_Test.head(10)
# Out:
#    Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0    Male     Yes          0      Graduate            No             5720
# 1    Male     Yes          1      Graduate            No             3076
# 2    Male     Yes          2      Graduate            No             5000
# 3    Male     Yes          2      Graduate            No             2340
# 4    Male      No          0  Not Graduate            No             3276
# 5    Male     Yes          0  Not Graduate           Yes             2165
# 6  Female      No          1  Not Graduate            No             2226
# 7    Male     Yes          2  Not Graduate            No             3881
# 8    Male     Yes          2      Graduate           NaN            13633
# 9    Male      No          0  Not Graduate            No             2400
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0       110.0             360.0             1.0
# ...

# %%
Data.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
Data.tail(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 604  LP002959  Female     Yes          1      Graduate            No
# 605  LP002960    Male     Yes          0  Not Graduate            No
# 606  LP002961    Male     Yes          1      Graduate            No
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 604            12000                0.0       496.0             360.0
# ...

# %%
Data.shape
# Out:
# (614, 13)

# %%
Data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
Maratial_Status = pd.get_dummies(Data.Married,drop_first = True)
Sex = pd.get_dummies(Data.Gender,drop_first = True)
Data = pd.concat([Data,Maratial_Status,Sex],axis=1)

# %%
Data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  Yes  Male
# 0             1.0         Urban           Y    0     1
# ...

# %%
Maratial_Status_Test = pd.get_dummies(Data_Test.Married,drop_first = True)
Sex_Test = pd.get_dummies(Data_Test.Gender,drop_first = True)
Data_Test = pd.concat([Data_Test,Maratial_Status_Test,Sex_Test],axis=1)

# %%
Data_Test.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male     Yes          0      Graduate            No             5720
# 1   Male     Yes          1      Graduate            No             3076
# 2   Male     Yes          2      Graduate            No             5000
# 3   Male     Yes          2      Graduate            No             2340
# 4   Male      No          0  Not Graduate            No             3276
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0       110.0             360.0             1.0
# 1               1500       126.0             360.0             1.0
# 2               1800       208.0             360.0             1.0
# 3               2546       100.0             360.0             NaN
# 4                  0        78.0             360.0             1.0
#
#   Property_Area  Yes  Male
# 0         Urban    1     1
# 1         Urban    1     1
# 2         Urban    1     1
# ...

# %%
Data = Data.rename(columns = {'Male':'Sex','Yes':'Maratial_Status'})
Data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
Data_Test = Data_Test.rename(columns = {'Male':'Sex','Yes':'Maratial_Status'})
Data_Test
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0     Male     Yes          0      Graduate            No             5720
# 1     Male     Yes          1      Graduate            No             3076
# 2     Male     Yes          2      Graduate            No             5000
# 3     Male     Yes          2      Graduate            No             2340
# 4     Male      No          0  Not Graduate            No             3276
# ..     ...     ...        ...           ...           ...              ...
# 362   Male     Yes         3+  Not Graduate           Yes             4009
# 363   Male     Yes          0      Graduate            No             4158
# 364   Male      No          0      Graduate            No             3250
# 365   Male     Yes          0      Graduate            No             5000
# 366   Male      No          0      Graduate           Yes             9200
#
# ...

# %%
Data = Data.drop(Data[['Gender','Married']],axis = 1)
Data
# Out:
#       Loan_ID Dependents     Education Self_Employed  ApplicantIncome  \
# 0    LP001002          0      Graduate            No             5849
# 1    LP001003          1      Graduate            No             4583
# 2    LP001005          0      Graduate           Yes             3000
# 3    LP001006          0  Not Graduate            No             2583
# 4    LP001008          0      Graduate            No             6000
# ..        ...        ...           ...           ...              ...
# 609  LP002978          0      Graduate            No             2900
# 610  LP002979         3+      Graduate            No             4106
# 611  LP002983          1      Graduate            No             8072
# 612  LP002984          2      Graduate            No             7583
# 613  LP002990          0      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
Data_Test = Data_Test.drop(Data_Test[['Gender','Married']],axis = 1)
Data_Test
# Out:
#     Dependents     Education Self_Employed  ApplicantIncome  \
# 0            0      Graduate            No             5720
# 1            1      Graduate            No             3076
# 2            2      Graduate            No             5000
# 3            2      Graduate            No             2340
# 4            0  Not Graduate            No             3276
# ..         ...           ...           ...              ...
# 362         3+  Not Graduate           Yes             4009
# 363          0      Graduate            No             4158
# 364          0      Graduate            No             3250
# 365          0      Graduate            No             5000
# 366          0      Graduate           Yes             9200
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                    0       110.0             360.0             1.0
# 1                 1500       126.0             360.0             1.0
# ...

# %%
Data['Self_Employed'] = Data['Self_Employed'].map({'Yes':1,"No":0})
Data
# Out:
#       Loan_ID Dependents     Education  Self_Employed  ApplicantIncome  \
# 0    LP001002          0      Graduate            0.0             5849
# 1    LP001003          1      Graduate            0.0             4583
# 2    LP001005          0      Graduate            1.0             3000
# 3    LP001006          0  Not Graduate            0.0             2583
# 4    LP001008          0      Graduate            0.0             6000
# ..        ...        ...           ...            ...              ...
# 609  LP002978          0      Graduate            0.0             2900
# 610  LP002979         3+      Graduate            0.0             4106
# 611  LP002983          1      Graduate            0.0             8072
# 612  LP002984          2      Graduate            0.0             7583
# 613  LP002990          0      Graduate            1.0             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
Data_Test['Self_Employed'] = Data_Test['Self_Employed'].map({'Yes':1,"No":0})
Data_Test
# Out:
#     Dependents     Education  Self_Employed  ApplicantIncome  \
# 0            0      Graduate            0.0             5720
# 1            1      Graduate            0.0             3076
# 2            2      Graduate            0.0             5000
# 3            2      Graduate            0.0             2340
# 4            0  Not Graduate            0.0             3276
# ..         ...           ...            ...              ...
# 362         3+  Not Graduate            1.0             4009
# 363          0      Graduate            0.0             4158
# 364          0      Graduate            0.0             3250
# 365          0      Graduate            0.0             5000
# 366          0      Graduate            1.0             9200
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                    0       110.0             360.0             1.0
# 1                 1500       126.0             360.0             1.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
Le = LabelEncoder()
Data['Education']=Le.fit_transform(Data['Education'])
Data['Property_Area']=Le.fit_transform(Data['Property_Area'])
Data_Test['Education']=Le.fit_transform(Data_Test['Education'])
Data_Test['Property_Area']=Le.fit_transform(Data_Test['Property_Area'])

# %%
Data['Education'].astype(int)
Data['Property_Area'].astype(int)
Data_Test['Education'].astype(int)
Data_Test['Property_Area'].astype(int)
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 362    2
# 363    2
# 364    1
# 365    0
# 366    0
# Name: Property_Area, Length: 367, dtype: int32

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Dependents         599 non-null    object
#  2   Education          614 non-null    int32
#  3   Self_Employed      582 non-null    float64
#  4   ApplicantIncome    614 non-null    int64
#  5   CoapplicantIncome  614 non-null    float64
#  6   LoanAmount         592 non-null    float64
#  7   Loan_Amount_Term   600 non-null    float64
#  8   Credit_History     564 non-null    float64
#  9   Property_Area      614 non-null    int32
#  10  Loan_Status        614 non-null    object
#  11  Maratial_Status    614 non-null    uint8
#  12  Sex                614 non-null    uint8
# dtypes: float64(5), int32(2), int64(1), object(3), uint8(2)
# memory usage: 49.3+ KB

# %%
Data_Test.head()
# Out:
#   Dependents  Education  Self_Employed  ApplicantIncome  CoapplicantIncome  \
# 0          0          0            0.0             5720                  0
# 1          1          0            0.0             3076               1500
# 2          2          0            0.0             5000               1800
# 3          2          0            0.0             2340               2546
# 4          0          1            0.0             3276                  0
#
#    LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  \
# 0       110.0             360.0             1.0              2
# 1       126.0             360.0             1.0              2
# 2       208.0             360.0             1.0              2
# 3       100.0             360.0             NaN              2
# 4        78.0             360.0             1.0              2
#
#    Maratial_Status  Sex
# 0                1    1
# 1                1    1
# 2                1    1
# 3                1    1
# ...

# %%
Data.head()
# Out:
#     Loan_ID Dependents  Education  Self_Employed  ApplicantIncome  \
# 0  LP001002          0          0            0.0             5849
# 1  LP001003          1          0            0.0             4583
# 2  LP001005          0          0            1.0             3000
# 3  LP001006          0          1            0.0             2583
# 4  LP001008          0          0            0.0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#    Property_Area Loan_Status  Maratial_Status  Sex
# 0              2           Y                0    1
# 1              0           N                1    1
# ...

# %%
Data['Dependents']= Data['Dependents'].map({'0':0,'1':1,'2':2,'3+':3})
Data_Test['Dependents']= Data_Test['Dependents'].map({'0':0,'1':1,'2':2,'3+':3})

# %%
Data['Loan_Amount_Term'].value_counts()
# Out:
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 84.0       4
# 240.0      4
# 120.0      3
# 36.0       2
# 60.0       2
# 12.0       1
# Name: Loan_Amount_Term, dtype: int64

# %%
Data['Loan_Amount_Term'] = Data['Loan_Amount_Term'].fillna(Data['Loan_Amount_Term'].mean())
Data['Dependents'] = Data['Dependents'].fillna(Data['Dependents'].median())
Data['LoanAmount'] = Data['LoanAmount'].fillna(Data['LoanAmount'].mean())
Data['Self_Employed'] = Data['Self_Employed'].fillna(Data['Self_Employed'].median())
Data['Credit_History'] = Data['Credit_History'].fillna(Data['Credit_History'].median())
Data_Test['Loan_Amount_Term'] = Data_Test['Loan_Amount_Term'].fillna(Data['Loan_Amount_Term'].mean())
Data_Test['Dependents'] = Data_Test['Dependents'].fillna(Data_Test['Dependents'].median())
Data_Test['LoanAmount'] = Data_Test['LoanAmount'].fillna(Data_Test['LoanAmount'].mean())
Data_Test['Self_Employed'] = Data_Test['Self_Employed'].fillna(Data_Test['Self_Employed'].median())
Data_Test['Credit_History'] = Data_Test['Credit_History'].fillna(Data_Test['Credit_History'].median())

# %%
Data.isnull().sum()
# Out:
# Loan_ID              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# Maratial_Status      0
# Sex                  0
# dtype: int64

# %%
Data_Test.isnull().sum()
# Out:
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Maratial_Status      0
# Sex                  0
# dtype: int64

# %%
Data.head(10)
# Out:
#     Loan_ID  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0  LP001002         0.0          0            0.0             5849
# 1  LP001003         1.0          0            0.0             4583
# 2  LP001005         0.0          0            1.0             3000
# 3  LP001006         0.0          1            0.0             2583
# 4  LP001008         0.0          0            0.0             6000
# 5  LP001011         2.0          0            1.0             5417
# 6  LP001013         0.0          1            0.0             2333
# 7  LP001014         3.0          0            0.0             3036
# 8  LP001018         2.0          0            0.0             4006
# 9  LP001020         1.0          0            0.0            12841
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0             1.0
# 1             1508.0  128.000000             360.0             1.0
# ...

# %%
Data['Education'].value_counts()/614*100
# Out:
# 0    78.175896
# 1    21.824104
# Name: Education, dtype: float64

# %% [markdown]
# # Uni-Variate Data Analysis

# %%
sns.countplot(Data['Dependents'])

# %%
sns.countplot(Data['Sex'])

# %%
Data['Dependents'].value_counts()/614*100
# Out:
# 0.0    58.631922
# 1.0    16.612378
# 2.0    16.449511
# 3.0     8.306189
# Name: Dependents, dtype: float64

# %%
sns.countplot(Data['Education'])

# %%
Data['Education'].value_counts()/614*100
# Out:
# 0    78.175896
# 1    21.824104
# Name: Education, dtype: float64

# %%
sns.countplot(Data['Property_Area'])

# %%
Data['Property_Area'].value_counts()/614*100
# Out:
# 1    37.947883
# 2    32.899023
# 0    29.153094
# Name: Property_Area, dtype: float64

# %%
sns.countplot(Data['Maratial_Status'])

# %%
Data['Maratial_Status'].value_counts()/614*100
# Out:
# 1    64.820847
# 0    35.179153
# Name: Maratial_Status, dtype: float64

# %%
sns.distplot(Data['LoanAmount'])

# %%
Data[Data["LoanAmount"]>390].shape
# Out:
# (15, 13)

# %%
Data = Data[Data["LoanAmount"]<500 ]

# %%
sns.boxplot(Data['LoanAmount'])

# %%
sns.distplot(Data['ApplicantIncome'])

# %%
Data[Data["ApplicantIncome"]>7500].shape
# Out:
# (87, 13)

# %%
Data = Data[Data["ApplicantIncome"]<7500]

# %%
sns.boxplot(Data['ApplicantIncome'])

# %%
Data[Data["CoapplicantIncome"]>5500].shape
# Out:
# (20, 13)

# %%
Data = Data[Data["CoapplicantIncome"]<5500]

# %%
sns.boxplot(Data['CoapplicantIncome'])

# %%
Data.shape
# Out:
# (500, 13)

# %%
sns.countplot(Data['Loan_Status'])

# %%
Data['Loan_Amount_Term'].value_counts()/614*100
# Out:
# 360.0    68.241042
# 180.0     5.048860
# 480.0     2.280130
# 342.0     2.117264
# 300.0     1.465798
# 84.0      0.651466
# 240.0     0.488599
# 120.0     0.488599
# 36.0      0.325733
# 12.0      0.162866
# 60.0      0.162866
# Name: Loan_Amount_Term, dtype: float64

# %%
Data.describe()
# Out:
#        Dependents   Education  Self_Employed  ApplicantIncome  \
# count  500.000000  500.000000     500.000000         500.0000
# mean     0.698000    0.258000       0.110000        3739.9760
# std      0.986277    0.437972       0.313203        1391.4299
# min      0.000000    0.000000       0.000000         150.0000
# 25%      0.000000    0.000000       0.000000        2693.2500
# 50%      0.000000    0.000000       0.000000        3500.0000
# 75%      1.000000    1.000000       0.000000        4618.2500
# max      3.000000    1.000000       1.000000        7451.0000
#
#        CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# count         500.000000  500.000000        500.000000      500.000000
# mean         1351.431840  124.207662        343.692000        0.850000
# std          1368.515812   45.196969         64.117199        0.357429
# min             0.000000    9.000000         12.000000        0.000000
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(Data.drop(['Loan_Status','Loan_ID'],axis = 1),
                                                 Data['Loan_Status'],test_size = 0.4,random_state = 402)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(random_state=50)

# %%
lr.fit(X_train,Y_train)
# Out:
# C:\Users\Vaibhav Banga\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=50, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
Pred = lr.predict(X_test)

# %%
Pred_tr = lr.predict(X_train)

# %%
from sklearn.metrics import accuracy_score,r2_score,confusion_matrix,classification_report

# %%
cm = confusion_matrix(Y_test,Pred)
cm
# Out:
# array([[ 30,  44],
#        [  3, 123]], dtype=int64)

# %%
accuracy_score(Y_test,Pred)
# Out:
# 0.765

# %%
accuracy_score(Y_train,Pred_tr)
# Out:
# 0.8466666666666667

# %%
print(X_train.shape)
# Out:
# (300, 11)

# %%
print(Y_train.shape)
# Out:
# (300,)

# %%
print(classification_report(Y_test,Pred))
# Out:
#               precision    recall  f1-score   support
#
#            N       0.91      0.41      0.56        74
#            Y       0.74      0.98      0.84       126
#
#     accuracy                           0.77       200
#    macro avg       0.82      0.69      0.70       200
# weighted avg       0.80      0.77      0.74       200

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier()
RF.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
Pred_Rf_ = RF.predict(X_test)

# %%
Pred_Rf = RF.predict(X_train)

# %%
accuracy_score(Y_test,Pred_Rf_)
# Out:
# 0.745

# %%
accuracy_score(Y_train,Pred_Rf)
# Out:
# 1.0

# %%
Submission_Predict = lr.predict(Data_Test)
Submission_Predict
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y',
#        'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N',
#        'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N',
# ...
